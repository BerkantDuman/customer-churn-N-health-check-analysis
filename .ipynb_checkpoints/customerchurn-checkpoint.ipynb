# %%
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt
from sklearn import preprocessing
# %matplotlib inline

# %%
dataFM = pd.read_excel("customers2.xlsx", engine="openpyxl")

# %%
label_encoder = preprocessing.LabelEncoder() # Karakter olanları encodelarayark numeric hale getiriyoruz
dataFM['state'] = label_encoder.fit_transform(dataFM['state'])
dataFM['international plan'] = label_encoder.fit_transform(dataFM['international plan'])
dataFM['voice mail plan'] = label_encoder.fit_transform(dataFM['voice mail plan'])

# %%
dataFM.head()
# Out:
#    state  account length  area code phone number  international plan  \
# 0     16             128        415     382-4657                   0
# 1     35             107        415     371-7191                   0
# 2     31             137        415     358-1921                   0
# 3     35              84        408     375-9999                   1
# 4     36              75        415     330-6626                   1
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn import neighbors, datasets, preprocessing
from sklearn.metrics import accuracy_score

# %%
dataFM = dataFM.drop("phone number", axis=1)
x = dataFM.drop("churn", axis=1).values
y = dataFM["churn"].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3 , random_state = 0) # test ve eğitim verisi olarak ayırdık
scaler = preprocessing.StandardScaler().fit(x_train) # Veriler ölçeklendi
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# ### KNN

# %%
knn = neighbors.KNeighborsClassifier(n_neighbors=5) #KNN modeli oluşturuldu
knn.fit(x_train, y_train)
knn_pred = knn.predict(x_test)
print("KNN Accuracy: ", accuracy_score(y_test, knn_pred) ) # başarı yüzdesi
# Out:
# KNN Accuracy:  0.903

# %%
knncompare = pd.DataFrame(y_test, columns = ["Gerçek Y"])
knncompare2 = pd.DataFrame(knn_pred, columns = ["Tahmin Y"])
knntahminDF = pd.concat([compare, compare2], axis = 1)
knntahminDF.head()
# Out:
#    Gerçek Y  Tahmin Y
# 0     False     False
# 1     False     False
# 2     False     False
# 3     False     False
# 4      True      True

# %% [markdown]
# ### SVM with rbf

# %%
from sklearn import svm
clf = svm.SVC()
clf.fit(x_train, y_train)
svm_pred = clf.predict(x_test)
print("SVM with rbf Accuracy: ", accuracy_score(y_test, svm_pred) ) # başarı yüzdesi
# Out:
# rbf
# SVM Accuracy:  0.925

# %%
svmcompare = pd.DataFrame(y_test, columns = ["Gerçek Y"])
svmcompare2 = pd.DataFrame(svm_pred, columns = ["Tahmin Y"])
svmtahminDF = pd.concat([compare, compare2], axis = 1)
svmtahminDF.head()
# Out:
#    Gerçek Y  Tahmin Y
# 0     False     False
# 1     False     False
# 2     False     False
# 3     False     False
# 4      True      True

# %% [markdown]
# ### SVM with RBF

# %%
from sklearn import svm
clf = svm.SVC(kernel="linear")
clf.fit(x_train, y_train)
svm_pred = clf.predict(x_test)
print("SVM with linear Accuracy: ", accuracy_score(y_test, svm_pred) ) # başarı yüzdesi
# Out:
# SVM with linear Accuracy:  0.862

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train, y_train)
gnb_pred = gnb.predict(x_test)
print("GNB Accuracy: ", accuracy_score(y_test, gnb_pred) ) # başarı yüzdesi
# Out:
# GNB Accuracy:  0.857

# %% [markdown]
# ### Desicion Tree

# %%
from sklearn import tree
d_tree = tree.DecisionTreeClassifier()
d_tree.fit(x_train, y_train)
dtree_pred = d_tree.predict(x_test)
print("Desicion Tree Accuracy: ", accuracy_score(y_test, dtree_pred) )
# Out:
# Desicion Tree Accuracy:  0.901

# %%
tree.plot_tree(d_tree)
# Out:
# [Text(273.6028373161765, 211.7178947368421, 'X[8] <= 1.536\ngini = 0.252\nsamples = 2333\nvalue = [1988, 345]'),
#  Text(228.16096875000002, 200.2736842105263, 'X[18] <= 1.461\ngini = 0.205\nsamples = 2176\nvalue = [1924, 252]'),
#  Text(197.01605514705884, 188.82947368421054, 'X[3] <= 1.401\ngini = 0.147\nsamples = 2005\nvalue = [1845, 160]'),
#  Text(162.16669852941178, 177.38526315789474, 'X[8] <= 0.82\ngini = 0.096\nsamples = 1831\nvalue = [1738, 93]'),
#  Text(124.76633823529413, 165.94105263157894, 'X[1] <= 3.091\ngini = 0.052\nsamples = 1579\nvalue = [1537, 42]'),
#  Text(107.76785294117649, 154.49684210526317, 'X[5] <= 2.882\ngini = 0.051\nsamples = 1576\nvalue = [1535, 41]'),
#  Text(80.07300000000001, 143.05263157894737, 'X[1] <= -0.304\ngini = 0.05\nsamples = 1572\nvalue = [1532, 40]'),
#  Text(30.985411764705887, 131.60842105263157, 'X[7] <= -0.939\ngini = 0.025\nsamples = 621\nvalue = [613, 8]'),
# ...

# %% [markdown]
# ### Neural Network Model

# %%
from sklearn.neural_network import MLPClassifier
nn = MLPClassifier(
    solver="lbfgs", alpha=1e-5, hidden_layer_sizes= (5, 2), random_state=1)
nn.fit(x_train, y_train)
nn_pred = nn.predict(x_test)
print("Neural Network Accuracy: ", accuracy_score(y_test, nn_pred) )
# Out:
# Neural Network Accuracy:  0.94
# /opt/anaconda/2020.10/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:471: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
